# %%
import pandas as pd

df = pd.read_csv("data/derived/languages_master.csv")
df
# Out:
#           lang_id canonical_name source_flags    types extensions  \
# 0               +     !@$%^&*()+      esolang  esolang        NaN
# 1             +-+       +=-, -=+      esolang  esolang        NaN
# 2           +-pda        +-= PDA      esolang  esolang        NaN
# 3         +-quote       +-"quote      esolang  esolang        NaN
# 4         +output        +Output      esolang  esolang        NaN
# ...           ...            ...          ...      ...        ...
# 11852     zyxonia        Zyxonia      esolang  esolang        NaN
# 11853  zyzzogeton     Zyzzogeton      esolang  esolang        NaN
# 11854          zz             zz         pldb      NaN        NaN
# 11855    zzt-flip       ZZT-Flip      esolang  esolang        NaN
# 11856         zzz            Zzz      esolang  esolang        NaN
#
#        first_appeared homepage  paradigms  typing  designed_by  ...  in_pldb  \
# 0                 NaN      NaN        NaN     NaN          NaN  ...    False
# 1                 NaN      NaN        NaN     NaN          NaN  ...    False
# 2                 NaN      NaN        NaN     NaN          NaN  ...    False
# 3                 NaN      NaN        NaN     NaN          NaN  ...    False
# 4                 NaN      NaN        NaN     NaN          NaN  ...    False
# ...               ...      ...        ...     ...          ...  ...      ...
# 11852             NaN      NaN        NaN     NaN          NaN  ...    False
# 11853             NaN      NaN        NaN     NaN          NaN  ...    False
# 11854             NaN      NaN        NaN     NaN          NaN  ...     True
# 11855             NaN      NaN        NaN     NaN          NaN  ...    False
# 11856             NaN      NaN        NaN     NaN          NaN  ...    False
#
#        in_linguist in_wikipedia in_esolang  has_extensions  has_paradigm  \
# 0            False        False       True           False         False
# 1            False        False       True           False         False
# 2            False        False       True           False         False
# 3            False        False       True           False         False
# 4            False        False       True           False         False
# ...            ...          ...        ...             ...           ...
# 11852        False        False       True           False         False
# 11853        False        False       True           False         False
# 11854        False        False      False           False         False
# 11855        False        False       True           False         False
# 11856        False        False       True           False         False
#
#        has_typing  has_hello_world  source_count  alias_count
# 0           False            False             1            1
# 1           False            False             1            1
# 2           False            False             1            1
# 3           False            False             1            1
# 4           False            False             1            1
# ...           ...              ...           ...          ...
# 11852       False            False             1            1
# 11853       False            False             1            1
# 11854       False            False             1            1
# 11855       False            False             1            1
# 11856       False            False             1            1
#
# [11857 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['lang_id', 'canonical_name', 'source_flags', 'types', 'extensions',
#        'first_appeared', 'homepage', 'paradigms', 'typing', 'designed_by',
#        'influenced_by', 'hello_world', 'linguist_key', 'evidence_urls',
#        'notes', 'in_pldb', 'in_linguist', 'in_wikipedia', 'in_esolang',
#        'has_extensions', 'has_paradigm', 'has_typing', 'has_hello_world',
#        'source_count', 'alias_count'],
#       dtype='object')

# %%
# “Likely DSLs” (heuristic: has typing/paradigm or extensions, but not in Linguist;) ?
dsls = df[df.in_pldb & ~df.in_linguist & (df.has_typing | df.has_paradigm | df.has_extensions)]

# %%
# “Research/historical breadth, but with some signal”?
dfr = df[df.in_pldb & (df.has_paradigm | df.has_typing | df.has_extensions)] 
# “Industrial-ish” list?
dfi = df[(df.in_linguist | df.in_wikipedia) & (df.has_extensions | df.has_paradigm)]

# %%
dfi
# Out:
#                    lang_id       canonical_name             source_flags  \
# 65           1c-enterprise        1C Enterprise            linguist;pldb
# 87     2-dimensional-array  2-Dimensional Array                 linguist
# 179                     4d                   4D                 linguist
# 295                   abap                 ABAP  linguist;pldb;wikipedia
# 296               abap-cds             ABAP CDS                 linguist
# ...                    ...                  ...                      ...
# 11789               zephir               Zephir            linguist;pldb
# 11810                  zig                  Zig            linguist;pldb
# 11814                  zil                  ZIL            linguist;pldb
# 11817                zimpl                Zimpl            linguist;pldb
# 11826               zmodel               Zmodel                 linguist
#
#       types         extensions  first_appeared homepage  paradigms  typing  \
# 65      NaN           .bsl .os             NaN      NaN        NaN     NaN
# 87      NaN               .2da             NaN      NaN        NaN     NaN
# 179     NaN               .4dm             NaN      NaN        NaN     NaN
# 295     NaN              .abap             NaN      NaN        NaN     NaN
# 296     NaN            .asddls             NaN      NaN        NaN     NaN
# ...     ...                ...             ...      ...        ...     ...
# 11789   NaN               .zep             NaN      NaN        NaN     NaN
# 11810   NaN      .zig .zig.zon             NaN      NaN        NaN     NaN
# 11814   NaN          .mud .zil             NaN      NaN        NaN     NaN
# 11817   NaN  .zimpl .zmpl .zpl             NaN      NaN        NaN     NaN
# 11826   NaN            .zmodel             NaN      NaN        NaN     NaN
#
#        designed_by  ...  in_pldb  in_linguist in_wikipedia in_esolang  \
# 65             NaN  ...     True         True        False      False
# 87             NaN  ...    False         True        False      False
# 179            NaN  ...    False         True        False      False
# 295            NaN  ...     True         True         True      False
# 296            NaN  ...    False         True        False      False
# ...            ...  ...      ...          ...          ...        ...
# 11789          NaN  ...     True         True        False      False
# 11810          NaN  ...     True         True        False      False
# 11814          NaN  ...     True         True        False      False
# 11817          NaN  ...     True         True        False      False
# 11826          NaN  ...    False         True        False      False
#
#        has_extensions  has_paradigm  has_typing  has_hello_world  \
# 65               True         False       False            False
# 87               True         False       False            False
# 179              True         False       False            False
# 295              True         False       False            False
# 296              True         False       False            False
# ...               ...           ...         ...              ...
# 11789            True         False       False            False
# 11810            True         False       False            False
# 11814            True         False       False            False
# 11817            True         False       False            False
# 11826            True         False       False            False
#
#        source_count  alias_count
# 65                2            1
# 87                1            1
# 179               1            1
# 295               2            1
# 296               1            1
# ...             ...          ...
# 11789             2            1
# 11810             2            1
# 11814             2            1
# 11817             2            1
# 11826             1            1
#
# [743 rows x 25 columns]
