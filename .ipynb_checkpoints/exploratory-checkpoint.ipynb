# %%
import pandas as pd

df = pd.read_csv("data/derived/languages.csv")
df
# Out:
#           lang_id canonical_name source_flags    types extensions  \
# 0               +     !@$%^&*()+      esolang  esolang        NaN
# 1             +-+       +=-, -=+      esolang  esolang        NaN
# 2           +-pda        +-= PDA      esolang  esolang        NaN
# 3         +-quote       +-"quote      esolang  esolang        NaN
# 4         +output        +Output      esolang  esolang        NaN
# ...           ...            ...          ...      ...        ...
# 11852     zyxonia        Zyxonia      esolang  esolang        NaN
# 11853  zyzzogeton     Zyzzogeton      esolang  esolang        NaN
# 11854          zz             zz         pldb      NaN        NaN
# 11855    zzt-flip       ZZT-Flip      esolang  esolang        NaN
# 11856         zzz            Zzz      esolang  esolang        NaN
#
#        first_appeared homepage  paradigms  typing  designed_by  ...  \
# 0                 NaN      NaN        NaN     NaN          NaN  ...
# 1                 NaN      NaN        NaN     NaN          NaN  ...
# 2                 NaN      NaN        NaN     NaN          NaN  ...
# 3                 NaN      NaN        NaN     NaN          NaN  ...
# 4                 NaN      NaN        NaN     NaN          NaN  ...
# ...               ...      ...        ...     ...          ...  ...
# 11852             NaN      NaN        NaN     NaN          NaN  ...
# 11853             NaN      NaN        NaN     NaN          NaN  ...
# 11854             NaN      NaN        NaN     NaN          NaN  ...
# 11855             NaN      NaN        NaN     NaN          NaN  ...
# 11856             NaN      NaN        NaN     NaN          NaN  ...
#
#             pygments_module  pygments_class pygments_aliases  \
# 0      pygments.lexers.mojo            Mojo           mojo;🔥
# 1      pygments.lexers.mojo            Mojo           mojo;🔥
# 2      pygments.lexers.mojo            Mojo           mojo;🔥
# 3      pygments.lexers.mojo            Mojo           mojo;🔥
# 4      pygments.lexers.mojo            Mojo           mojo;🔥
# ...                     ...             ...              ...
# 11852  pygments.lexers.mojo            Mojo           mojo;🔥
# 11853  pygments.lexers.mojo            Mojo           mojo;🔥
# 11854  pygments.lexers.mojo            Mojo           mojo;🔥
# 11855  pygments.lexers.mojo            Mojo           mojo;🔥
# 11856  pygments.lexers.mojo            Mojo           mojo;🔥
#
#       pygments_filenames              pygments_mimetypes  in_rosettacode  \
# 0             *.mojo;*.🔥  text/x-mojo;application/x-mojo            True
# 1             *.mojo;*.🔥  text/x-mojo;application/x-mojo           False
# 2             *.mojo;*.🔥  text/x-mojo;application/x-mojo           False
# 3             *.mojo;*.🔥  text/x-mojo;application/x-mojo           False
# 4             *.mojo;*.🔥  text/x-mojo;application/x-mojo           False
# ...                  ...                             ...             ...
# 11852         *.mojo;*.🔥  text/x-mojo;application/x-mojo           False
# 11853         *.mojo;*.🔥  text/x-mojo;application/x-mojo           False
# 11854         *.mojo;*.🔥  text/x-mojo;application/x-mojo           False
# 11855         *.mojo;*.🔥  text/x-mojo;application/x-mojo           False
# 11856         *.mojo;*.🔥  text/x-mojo;application/x-mojo           False
#
#        rosettacode_name                    rosettacode_url  \
# 0                  Mojo  https://rosettacode.org/wiki/Mojo
# 1                   NaN                                NaN
# 2                   NaN                                NaN
# 3                   NaN                                NaN
# 4                   NaN                                NaN
# ...                 ...                                ...
# 11852               NaN                                NaN
# 11853               NaN                                NaN
# 11854               NaN                                NaN
# 11855               NaN                                NaN
# 11856               NaN                                NaN
#
#        rosettacode_summary  rosettacode_tasks_count
# 0                      NaN                      4.0
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
# ...                    ...                      ...
# 11852                  NaN                      NaN
# 11853                  NaN                      NaN
# 11854                  NaN                      NaN
# 11855                  NaN                      NaN
# 11856                  NaN                      NaN
#
# [11857 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['lang_id', 'canonical_name', 'source_flags', 'types', 'extensions',
#        'first_appeared', 'homepage', 'paradigms', 'typing', 'designed_by',
#        'influenced_by', 'hello_world', 'linguist_key', 'evidence_urls',
#        'notes', 'in_pldb', 'in_linguist', 'in_wikipedia', 'in_esolang',
#        'has_extensions', 'has_paradigm', 'has_typing', 'has_hello_world',
#        'source_count', 'alias_count', 'hyperpolyglot_name', 'in_hyperpolyglot',
#        'hp_type', 'hp_group', 'hp_color', 'pygments_name', 'in_pygments',
#        'pygments_module', 'pygments_class', 'pygments_aliases',
#        'pygments_filenames', 'pygments_mimetypes', 'in_rosettacode',
#        'rosettacode_name', 'rosettacode_url', 'rosettacode_summary',
#        'rosettacode_tasks_count'],
#       dtype='object')

# %%
# “Likely DSLs” (heuristic: has typing/paradigm or extensions, but not in Linguist;) ?
dsls = df[df.in_pldb & ~df.in_linguist & (df.has_typing | df.has_paradigm | df.has_extensions)]

# %%
# “Research/historical breadth, but with some signal”?
dfr = df[df.in_pldb & (df.has_paradigm | df.has_typing | df.has_extensions)] 
# “Industrial-ish” list?
dfi = df[(df.in_linguist | df.in_wikipedia) & (df.has_extensions | df.has_paradigm)]

# %%
dfi
# Out:
#                    lang_id       canonical_name             source_flags  \
# 65           1c-enterprise        1C Enterprise            linguist;pldb
# 87     2-dimensional-array  2-Dimensional Array                 linguist
# 179                     4d                   4D                 linguist
# 295                   abap                 ABAP  linguist;pldb;wikipedia
# 296               abap-cds             ABAP CDS                 linguist
# ...                    ...                  ...                      ...
# 11789               zephir               Zephir            linguist;pldb
# 11810                  zig                  Zig            linguist;pldb
# 11814                  zil                  ZIL            linguist;pldb
# 11817                zimpl                Zimpl            linguist;pldb
# 11826               zmodel               Zmodel                 linguist
#
#       types         extensions  first_appeared homepage  paradigms  typing  \
# 65      NaN           .bsl .os             NaN      NaN        NaN     NaN
# 87      NaN               .2da             NaN      NaN        NaN     NaN
# 179     NaN               .4dm             NaN      NaN        NaN     NaN
# 295     NaN              .abap             NaN      NaN        NaN     NaN
# 296     NaN            .asddls             NaN      NaN        NaN     NaN
# ...     ...                ...             ...      ...        ...     ...
# 11789   NaN               .zep             NaN      NaN        NaN     NaN
# 11810   NaN      .zig .zig.zon             NaN      NaN        NaN     NaN
# 11814   NaN          .mud .zil             NaN      NaN        NaN     NaN
# 11817   NaN  .zimpl .zmpl .zpl             NaN      NaN        NaN     NaN
# 11826   NaN            .zmodel             NaN      NaN        NaN     NaN
#
#        designed_by  ...           pygments_module  pygments_class  \
# 65             NaN  ...      pygments.lexers.data            YAML
# 87             NaN  ...      pygments.lexers.mojo            Mojo
# 179            NaN  ...      pygments.lexers.data            YAML
# 295            NaN  ...  pygments.lexers.business            ABAP
# 296            NaN  ...      pygments.lexers.mojo            Mojo
# ...            ...  ...                       ...             ...
# 11789          NaN  ...       pygments.lexers.php          Zephir
# 11810          NaN  ...       pygments.lexers.zig             Zig
# 11814          NaN  ...      pygments.lexers.data            YAML
# 11817          NaN  ...      pygments.lexers.data            YAML
# 11826          NaN  ...      pygments.lexers.mojo            Mojo
#
#       pygments_aliases pygments_filenames              pygments_mimetypes  \
# 65                yaml       *.yaml;*.yml                     text/x-yaml
# 87              mojo;🔥         *.mojo;*.🔥  text/x-mojo;application/x-mojo
# 179               yaml       *.yaml;*.yml                     text/x-yaml
# 295               abap      *.abap;*.ABAP                     text/x-abap
# 296             mojo;🔥         *.mojo;*.🔥  text/x-mojo;application/x-mojo
# ...                ...                ...                             ...
# 11789           zephir              *.zep                             NaN
# 11810              zig              *.zig                        text/zig
# 11814             yaml       *.yaml;*.yml                     text/x-yaml
# 11817             yaml       *.yaml;*.yml                     text/x-yaml
# 11826           mojo;🔥         *.mojo;*.🔥  text/x-mojo;application/x-mojo
#
#        in_rosettacode  rosettacode_name                    rosettacode_url  \
# 65               True                1C    https://rosettacode.org/wiki/1C
# 87              False               NaN                                NaN
# 179              True                4D    https://rosettacode.org/wiki/4D
# 295              True              ABAP  https://rosettacode.org/wiki/ABAP
# 296             False               NaN                                NaN
# ...               ...               ...                                ...
# 11789           False               NaN                                NaN
# 11810            True               Zig   https://rosettacode.org/wiki/Zig
# 11814           False               NaN                                NaN
# 11817           False               NaN                                NaN
# 11826           False               NaN                                NaN
#
#        rosettacode_summary  rosettacode_tasks_count
# 65                     NaN                      2.0
# 87                     NaN                      NaN
# 179                    NaN                      5.0
# 295                    NaN                     70.0
# 296                    NaN                      NaN
# ...                    ...                      ...
# 11789                  NaN                      NaN
# 11810                  NaN                    319.0
# 11814                  NaN                      NaN
# 11817                  NaN                      NaN
# 11826                  NaN                      NaN
#
# [743 rows x 42 columns]

# %%
len(df["pygments_filenames"].unique())
# Out:
# 243
